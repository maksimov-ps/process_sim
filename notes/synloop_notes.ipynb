# %% [markdown]
# ## Derivation of Mass Balance
#
# We start from the general form:
#
# $$ \frac{dC}{dt} = -r(C) + \frac{F_{in}C_{in} - F_{out}C}{V} \tag{1} $$
# where:
# $C$ - concentration, $\frac{mol}{m^3}$
